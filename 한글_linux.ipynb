# %% [markdown]
# # 🐧 Korean Linux - 한국어로 리눅스 배우기
#
# 한국어 자연어로 리눅스 명령어를 실행하세요!
#
# **지원 명령어**: `ls`, `cd`, `mkdir`, `rm`, `cp`, `mv`, `find`, `cat`, `grep`, `head`, `tail`, `wc`, `ps`, `df`, `du`, `top`, `ping`, `curl`, `chmod`, `tar`

# %% [markdown]
# ## 1️⃣ 설치 및 초기화
#
# 아래 셀을 실행하면 모델이 자동으로 다운로드됩니다.

# %%
# 필요한 패키지 설치
# !pip install -q huggingface_hub sentencepiece

# 저장소 클론
# !git clone -q https://github.com/gyunggyung/korean-linux-colab.git 2>/dev/null || echo '이미 클론됨'
# %cd korean-linux-colab

# 모듈 임포트 및 초기화
import sys
sys.path.insert(0, 'src')
from korean_linux import 한글, setup

setup()

# %% [markdown]
# ## 2️⃣ 테스트용 예제 파일 생성

# %%
# 예제 파일들 생성
# !mkdir -p examples/data examples/logs

# 텍스트 파일
# !echo '안녕하세요! 테스트 파일입니다.' > examples/test.txt
# !echo '이것은 두 번째 줄입니다.' >> examples/test.txt
# !echo '한글 리눅스 프로젝트입니다.' >> examples/test.txt

# 로그 파일
# !echo '[INFO] 시스템 시작' > examples/logs/app.log
# !echo '[ERROR] 연결 실패' >> examples/logs/app.log
# !echo '[INFO] 재시도 중...' >> examples/logs/app.log
# !echo '[ERROR] 타임아웃 발생' >> examples/logs/app.log
# !echo '[INFO] 복구 완료' >> examples/logs/app.log

# 데이터 파일
# !echo 'name,age,city' > examples/data/users.csv
# !echo '김철수,25,서울' >> examples/data/users.csv
# !echo '이영희,30,부산' >> examples/data/users.csv

print('✅ 예제 파일 생성 완료!')
# !ls -la examples/

# %% [markdown]
# ## 3️⃣ 사용 예제
#
# `한글()` 함수에 원하는 작업을 한국어로 입력하세요!

# %%
# 파일 목록 보기
한글("현재 폴더의 파일 목록을 보여줘")

# %%
# 파일 내용 보기
한글("examples/test.txt 파일의 내용을 보여줘")

# %%
# 로그에서 에러 찾기
한글("examples/logs/app.log 파일에서 ERROR가 포함된 줄을 찾아줘")

# %%
# 디스크 사용량 확인
한글("디스크 사용량을 확인해줘")

# %%
# 폴더로 이동
한글("examples 폴더로 이동해줘")

# %%
# 네트워크 테스트
한글("구글에 핑 테스트를 해줘")

# %% [markdown]
# ## 4️⃣ 자유롭게 사용해보세요!

# %%
# 여기에 원하는 명령을 한국어로 입력해보세요
한글("여기에 명령을 입력하세요")

# %% [markdown]
# ---
#
# ## 📖 도움말
#
# **지원 명령어 예시:**
# - 파일 관리: "파일 목록 보여줘", "새 폴더 만들어줘", "파일 삭제해줘"
# - 파일 검색: "txt 파일 찾아줘", "error 단어가 포함된 줄 찾아줘"
# - 시스템: "디스크 사용량", "실행 중인 프로세스", "시스템 상태"
# - 네트워크: "핑 테스트", "웹페이지 가져와"
#
# **옵션:**
# ```python
# 한글("명령", execute=False)  # 명령어만 보고 실행하지 않음
# 한글("명령", confirm_dangerous=False)  # 위험 명령어 확인 건너뛰기
# ```
