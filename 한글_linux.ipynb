# %% [markdown]
# # 🐧 Korean Linux - 한국어로 리눅스 배우기
#
# 한국어 자연어로 리눅스 명령어를 실행하세요!
#
# **지원 명령어**: `ls`, `cd`, `mkdir`, `rm`, `cp`, `mv`, `find`, `cat`, `grep`, `head`, `tail`, `wc`, `ps`, `df`, `du`, `top`, `ping`, `curl`, `chmod`, `tar`

# %% [markdown]
# ## 1️⃣ 설치 및 초기화
#
# 아래 셀을 실행하면 필요한 패키지와 모델이 자동으로 설치/다운로드됩니다.

# %%
# ========================================
# 시스템 패키지 설치 (ping, curl 등)
# ========================================
# !apt-get update -qq
# !apt-get install -qq -y iputils-ping curl > /dev/null 2>&1
print('✅ 시스템 패키지 설치 완료')

# ========================================
# Python 패키지 설치
# ========================================
# !pip install -q huggingface_hub sentencepiece

# ========================================
# 저장소 클론 및 초기화
# ========================================
# !git clone -q https://github.com/gyunggyung/korean-linux-colab.git 2>/dev/null || (cd korean-linux-colab && git pull -q)
# %cd korean-linux-colab

import sys
sys.path.insert(0, 'src')
from korean_linux import 한글, setup
setup()

# %% [markdown]
# ## 2️⃣ 테스트용 예제 파일 생성

# %%
# 예제 파일들 생성
# !mkdir -p examples/data examples/logs backup

# 텍스트 파일
# !echo '안녕하세요! 테스트 파일입니다.' > test.txt
# !echo '이것은 두 번째 줄입니다.' >> test.txt
# !echo '한글 리눅스 프로젝트입니다.' >> test.txt

# 로그 파일
# !echo '[INFO] 시스템 시작' > app.log
# !echo '[ERROR] 연결 실패' >> app.log
# !echo '[INFO] 재시도 중...' >> app.log
# !echo '[ERROR] 타임아웃 발생' >> app.log
# !echo '[INFO] 복구 완료' >> app.log

# Python 파일
# !echo 'print("Hello World")' > main.py
# !echo 'def foo(): pass' >> main.py

print('✅ 예제 파일 생성 완료!')
# !ls -la

# %% [markdown]
# ## 3️⃣ 사용 예제
#
# `한글()` 함수에 원하는 작업을 한국어로 입력하세요!
#
# ### 📁 파일 관련

# %%
한글("현재 폴더에 뭐 있어?")

# %%
한글("test.txt 내용 보여줘")

# %%
한글("main.py 몇 줄이야?")

# %%
한글("app.log 마지막 3줄 보여줘")

# %% [markdown]
# ### 🔍 검색 관련

# %%
한글("app.log에서 'ERROR' 찾아줘")

# %%
한글("현재 폴더에서 txt 파일 찾아줘")

# %% [markdown]
# ### 💾 시스템 정보

# %%
한글("디스크 남은 용량 보여줘")

# %%
한글("현재 폴더 용량 얼마야?")

# %%
한글("실행 중인 프로세스 보여줘")

# %% [markdown]
# ### 🌐 네트워크

# %%
한글("구글에 핑 날려봐")

# %% [markdown]
# ### 📂 파일/폴더 관리

# %%
한글("newdir 폴더 만들어줘")

# %%
한글("test.txt를 backup/으로 복사해")

# %%
한글("examples 폴더로 이동해")

# %% [markdown]
# ## 4️⃣ 자유롭게 사용해보세요!

# %%
# 여기에 원하는 명령을 한국어로 입력해보세요
한글("backup 폴더에 뭐 있어?")

# %% [markdown]
# ---
#
# ## 📖 명령어 예제 정리
#
# | 작업 | 한국어 명령 |
# |------|------------|
# | 파일 목록 | `현재 폴더에 뭐 있어?` |
# | 파일 내용 | `test.txt 내용 보여줘` |
# | 줄 수 | `main.py 몇 줄이야?` |
# | 앞부분 보기 | `data.csv 첫 5줄만 봐` |
# | 뒷부분 보기 | `app.log 마지막 10줄 보여줘` |
# | 검색 | `app.log에서 'ERROR' 찾아줘` |
# | 파일 찾기 | `현재 폴더에서 txt 파일 찾아줘` |
# | 디스크 용량 | `디스크 남은 용량 보여줘` |
# | 폴더 용량 | `현재 폴더 용량 얼마야?` |
# | 프로세스 | `실행 중인 프로세스 보여줘` |
# | 네트워크 | `구글에 핑 날려봐` |
# | 폴더 만들기 | `backup 폴더 만들어줘` |
# | 파일 복사 | `test.txt를 backup/으로 복사해` |
# | 폴더 이동 | `examples 폴더로 이동해` |
# | 파일 삭제 | `test.txt 삭제해` |
